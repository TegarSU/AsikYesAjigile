# %%
import pandas as pd
import numpy as np

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt

target_names = ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4']

# %%
# #Path

# path_to_predict = "C:/Users/USER/Downloads/Tugas Akhir/AsikYesAjigile/predict/"

path_to_predict = "F:/178/Tugas Akhir/dataset/predict/"

# %%
# def angle(p1, p2):
#     ang1 = np.arctan2(*p1[::-1])
#     ang2 = np.arctan2(*p2[::-1])
#     return np.rad2deg((ang1 - ang2) % (2 * np.pi))

def plot_confusion_matrix(y_true, y_pred):

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           ylabel='True label',
           xlabel='Predicted label')

    fig.tight_layout()
    return ax

def emotion(a,v):
    if ((v > 0) & (a >= 0)):
        cluster = 'cluster 1'
    if ((v <= 0) & (a > 0)):
        cluster = 'cluster 2'
    if ((v < 0) & (a <= 0)):
        cluster = 'cluster 3'
    if ((v >= 0) & (a < 0)):
        cluster = 'cluster 4'
        
    return cluster

def get_val(data):
    v_pred = data.loc[:,2] #X
    a_pred = data.loc[:,0] #Y
    
    v_true = data.loc[:,3] #X
    a_true = data.loc[:,1] #Y
    
    return a_pred.tolist(), v_pred.tolist(), a_true.tolist(), v_true.tolist()

def plot_model(pred,true):
    plt.figure(figsize=(18, 6))

    plt.plot(pred, color='b') #Pred
    plt.plot(true, color='r') #True
    plt.show()
    
def plot_scatter(pred_a,pred_v,true_a,true_v):
    plt.figure(figsize=(15, 15))
    plt.xlim(-1,1)
    plt.ylim(-1,1)
    bbox=dict(boxstyle="round",
              ec=(1., 0.5, 0.5),
              fc=(1., 0.8, 0.8),
              alpha=0.6,
              color = 'yellow'
           )
    plt.text(0.6, 0.7, "cluster 1", size=30,
         ha="center", va="center",
         bbox=bbox
         )
    plt.text(-0.6, 0.7, "cluster 2", size=30,
         ha="center", va="center",
         bbox=bbox
         )
    plt.text(-0.6, -0.7, "cluster 3", size=30,
         ha="center", va="center",
         bbox=bbox
         )
    plt.text(0.6, -0.7, "cluster 4", size=30,
         ha="center", va="center",
         bbox=bbox
         )

    plt.scatter(pred_v,pred_a,color='b')
    plt.scatter(true_v,true_a,color='r')
    plt.axhline(y=0,color='black', label ="X")
    plt.axvline(x=0,color='black', label ="Y")
    plt.show()

def evaluate(true,pred):
    acc = accuracy_score(true, pred)
    print(classification_report(true, pred, target_names=target_names))
    plot_confusion_matrix(true, pred)
    print("\nAccuracy\t:",acc.round(2) * 100)
#     plt.matshow(mat)
#     plt.colorbar()
    plt.show()

# %% [markdown]
# # CASE 1

# %%
case = 'case1'
data = pd.read_excel(path_to_predict+case+'.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %%
print(true.count('cluster 1'))
print(true.count('cluster 2'))
print(true.count('cluster 3'))
print(true.count('cluster 4'))
# Out:
# 49
# 12
# 33
# 31

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %% [markdown]
# Score

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %%
evaluate(true,pred)
# Out:
#               precision    recall  f1-score   support
#
#    cluster 1       0.74      0.69      0.72        49
#    cluster 2       1.00      0.17      0.29        12
#    cluster 3       0.42      0.61      0.49        33
#    cluster 4       0.31      0.29      0.30        31
#
#    micro avg       0.52      0.52      0.52       125
#    macro avg       0.62      0.44      0.45       125
# weighted avg       0.57      0.52      0.51       125
#
#
# Accuracy	: 52.0

# %% [markdown]
# # CASE 2

# %%
case = 'case2'
data = pd.read_excel(path_to_predict+case+'.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
#               precision    recall  f1-score   support
#
#    cluster 1       0.61      0.61      0.61        49
#    cluster 2       0.00      0.00      0.00        12
#    cluster 3       0.45      0.61      0.52        33
#    cluster 4       0.37      0.35      0.36        31
#
#    micro avg       0.49      0.49      0.49       125
#    macro avg       0.36      0.39      0.37       125
# weighted avg       0.45      0.49      0.47       125
#
#
# Accuracy	: 49.0

# %% [markdown]
# # CASE 3

# %%
case = 'case3'
data = pd.read_excel(path_to_predict+case+'.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
#               precision    recall  f1-score   support
#
#    cluster 1       0.44      0.45      0.44        49
#    cluster 2       0.75      0.25      0.38        12
#    cluster 3       0.32      0.39      0.35        33
#    cluster 4       0.27      0.26      0.26        31
#
#    micro avg       0.37      0.37      0.37       125
#    macro avg       0.44      0.34      0.36       125
# weighted avg       0.39      0.37      0.37       125
#
#
# Accuracy	: 37.0

# %% [markdown]
# # CASE 4

# %%
case = 'case4'
data = pd.read_excel(path_to_predict+case+'.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
#               precision    recall  f1-score   support
#
#    cluster 1       0.56      0.63      0.60        49
#    cluster 2       0.00      0.00      0.00        12
#    cluster 3       0.39      0.42      0.41        33
#    cluster 4       0.33      0.35      0.34        31
#
#    micro avg       0.45      0.45      0.45       125
#    macro avg       0.32      0.35      0.34       125
# weighted avg       0.41      0.45      0.43       125
#
#
# Accuracy	: 45.0

# %% [markdown]
# # CASE 5

# %%
case = 'case5'
data = pd.read_excel(path_to_predict+case+'.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
#               precision    recall  f1-score   support
#
#    cluster 1       0.70      0.67      0.69        49
#    cluster 2       1.00      0.17      0.29        12
#    cluster 3       0.42      0.55      0.47        33
#    cluster 4       0.30      0.32      0.31        31
#
#    micro avg       0.50      0.50      0.50       125
#    macro avg       0.61      0.43      0.44       125
# weighted avg       0.56      0.50      0.50       125
#
#
# Accuracy	: 50.0

# %% [markdown]
# # CASE 6

# %%
case = 'case6'
data = pd.read_excel(path_to_predict+case+'.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
#               precision    recall  f1-score   support
#
#    cluster 1       0.74      0.71      0.73        49
#    cluster 2       1.00      0.25      0.40        12
#    cluster 3       0.45      0.64      0.52        33
#    cluster 4       0.32      0.29      0.31        31
#
#    micro avg       0.54      0.54      0.54       125
#    macro avg       0.63      0.47      0.49       125
# weighted avg       0.59      0.54      0.54       125
#
#
# Accuracy	: 54.0

# %% [markdown]
# # CASE 7

# %%
case = 'case7'
data = pd.read_excel(path_to_predict+case+'.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
#               precision    recall  f1-score   support
#
#    cluster 1       0.62      0.78      0.69        49
#    cluster 2       1.00      0.17      0.29        12
#    cluster 3       0.58      0.58      0.58        33
#    cluster 4       0.38      0.35      0.37        31
#
#    micro avg       0.56      0.56      0.56       125
#    macro avg       0.64      0.47      0.48       125
# weighted avg       0.59      0.56      0.54       125
#
#
# Accuracy	: 56.0

# %% [markdown]
# # CASE 8

# %%
case = 'case8'
data = pd.read_excel(path_to_predict+case+'.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
#               precision    recall  f1-score   support
#
#    cluster 1       0.70      0.63      0.67        49
#    cluster 2       1.00      0.17      0.29        12
#    cluster 3       0.42      0.58      0.49        33
#    cluster 4       0.32      0.35      0.34        31
#
#    micro avg       0.50      0.50      0.50       125
#    macro avg       0.61      0.43      0.44       125
# weighted avg       0.56      0.50      0.50       125
#
#
# Accuracy	: 50.0

# %% [markdown]
# # CASE 9

# %%
case = 'case9'
data = pd.read_excel(path_to_predict+case+'.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
#               precision    recall  f1-score   support
#
#    cluster 1       0.65      0.76      0.70        49
#    cluster 2       1.00      0.42      0.59        12
#    cluster 3       0.59      0.61      0.60        33
#    cluster 4       0.38      0.35      0.37        31
#
#    micro avg       0.58      0.58      0.58       125
#    macro avg       0.65      0.53      0.56       125
# weighted avg       0.60      0.58      0.58       125
#
#
# Accuracy	: 58.0

# %% [markdown]
# # CASE 10

# %%
case = 'case10'
data = pd.read_excel(path_to_predict+case+'.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
#               precision    recall  f1-score   support
#
#    cluster 1       0.65      0.73      0.69        49
#    cluster 2       0.83      0.42      0.56        12
#    cluster 3       0.59      0.61      0.60        33
#    cluster 4       0.40      0.39      0.39        31
#
#    micro avg       0.58      0.58      0.58       125
#    macro avg       0.62      0.54      0.56       125
# weighted avg       0.59      0.58      0.58       125
#
#
# Accuracy	: 58.0
