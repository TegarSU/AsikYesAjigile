# %%
import pandas as pd

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt

# %%
# #Path

# path_to_predict = "C:/Users/USER/Downloads/Tugas Akhir/AsikYesAjigile/predict/"

path_to_predict = "F:/178/Tugas Akhir/dataset/predict/"

# %%
def emotion(a,v):
    if ((v >= 5) & (a >= 5)):
        cluster = 'cluster 1'
    if ((v < 5) & (a >= 5)):
        cluster = 'cluster 2'
    if ((v < 5) & (a <= 5)):
        cluster = 'cluster 3'
    if ((v >= 5) & (a < 5)):
        cluster = 'cluster 4'
        
    return cluster

def get_val(data):
    v_pred = data.loc[:,2] #X
    a_pred = data.loc[:,0] #Y
    
    v_true = data.loc[:,3] #X
    a_true = data.loc[:,1] #Y
    
    return a_pred.tolist(), v_pred.tolist(), a_true.tolist(), v_true.tolist()

def plot_model(pred,true):
    plt.figure(figsize=(18, 6))

    plt.plot(pred, color='b') #Pred
    plt.plot(true, color='r') #True
    plt.show()
    
def plot_scatter(pred_a,pred_v,true_a,true_v):
    plt.figure(figsize=(18, 6))

    plt.scatter(pred_v,pred_a,color='b')
    plt.scatter(true_v,true_a,color='r')
    plt.axhline(y=5,color='black', label ="X")
    plt.axvline(x=5,color='black', label ="Y")
    plt.show()

def evaluate(true,pred):
    acc = accuracy_score(true, pred)
    mat = confusion_matrix(true, pred)
    print("\nAccuracy\t:",acc.round(2) * 100)
    plt.matshow(mat)
    plt.colorbar()
    plt.show()

# %% [markdown]
# # CASE 1

# %%
case = 'case1'
data = pd.read_excel(path_to_predict+case+'_svr.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
# Accuracy	: 61.0

# %% [markdown]
# # CASE 2

# %%
case = 'case2'
data = pd.read_excel(path_to_predict+case+'_svr.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
# Accuracy	: 61.0

# %% [markdown]
# # CASE 3

# %%
case = 'case3'
data = pd.read_excel(path_to_predict+case+'_svr.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
# Accuracy	: 62.0

# %% [markdown]
# # CASE 4

# %%
case = 'case4'
data = pd.read_excel(path_to_predict+case+'_svr.xlsx',header=None)
a_pred,v_pred,a_true,v_true = get_val(data)

# %%
# #Pred
pred = list()
true = list()

for a,v,at,vt in zip(a_pred,v_pred,a_true,v_true):
    pred.append(emotion(a,v))
    true.append(emotion(at,vt))

# %% [markdown]
# Plotting Valence

# %%
plot_model(v_pred,v_true)

# %% [markdown]
# Plotting Arousal

# %%
plot_model(a_pred,a_true)

# %% [markdown]
# Plotting Valence-Arousal

# %%
plot_scatter(a_pred,v_pred,a_true,v_true)

# %% [markdown]
# Score

# %%
evaluate(true,pred)
# Out:
# Accuracy	: 63.0
